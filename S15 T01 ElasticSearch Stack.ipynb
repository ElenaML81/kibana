# %% [markdown]
# ### S15 T01: Visualització interactiva amb ElasticSearch Stack

# %% [markdown]
# ### Nivell 1
#
# #### - Exercici 1
#
# Descarrega't Kibana i mostra algunes gràfiques utilitzant conjunts de dades d'Exemple.

# %% [markdown]
# For this exercice we will use a sample dataset that already exists in elastic web page: a dataset consisting of an e-Commerce store for clothes and accesories for Men and women.

# %% [markdown]
# For this dataset we have some visualizations already loaded that provide general info about transactions, revenues, median spending, items sold and more:

# %% [markdown]
# ![kibana4.png](attachment:kibana4.png)

# %% [markdown]
# We can filter this information to get the info we want, for instance, if we want to see info about transactions in **Women's Shoes Category** we can generate this visualizations using Filtering pannel in the dashboard:

# %% [markdown]
#  ![Kibana_women_shoes2.png](attachment:Kibana_women_shoes2.png)

# %% [markdown]
# ![Kibana_women_shoes.png](attachment:Kibana_women_shoes.png)

# %% [markdown]
# It is also possible to generate a Canvas with the percentages of revenues according to Category (accesories, clothing and shoes) and Gender (Men or Women):

# %% [markdown]
# ![kibana1.png](attachment:kibana1.png)

# %% [markdown]
# ### Nivell 2
#
# #### - Exercici 1
#
# Implementa un dashboard que visualitzi interactivament les dades que triïs.

# %% [markdown]
# For this exercise I have loaded a dataset containing worldwide sales of **Video Games** for the period betwween the years 1980-2015. The dataset contains video games whose total sales have been greater than 100,000 units.
#
# The dataset contains info about the Name, Platform, Year, Genre and Publisher. In terms of sales, it contains information on global sales, and also provides information into regions such as the US, Japan, Europe and the rest of the world. Sales are in Million units. If we open the dataset with pandas this is how it looks like:

# %%
import pandas as pd 

data = pd.read_csv('videogames.csv')
data.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# + **Explanation of the columns of the dataset**

# %% [markdown]
# + **Rank** : Ranking of overall sales
# + **Name** : The games name
# + **Platform** : Platform of the games release (i.e. PC,PS4, etc.)
# + **Year** : Year of the game's release
# + **Genre** : Genre of the game
# + **Publisher** : Publisher of the game
# + **NA_Sales** : Sales in North America (in millions)
# + **EU_Sales** : Sales in Europe (in millions)
# + **JP_Sales** : Sales in Japan (in millions)
# + **Other_Sales** : Sales in the rest of the world (in millions)
# + **Global_Sales** : Total worldwide sales

# %% [markdown]
# + **Creation of a dashboard**

# %% [markdown]
# With the information of the dataset we have created the following dashboard:

# %% [markdown]
# ![kibana%20Video%20games.png](attachment:kibana%20Video%20games.png)

# %% [markdown]
# We have 6 different types of visualizations:

# %% [markdown]
# * **Treemap**

# %% [markdown]
# ![games_1.png](attachment:games_1.png)

# %% [markdown]
# In this treemap we can visualize the percentage of the 15 most important Videogames platforms online according to the titles sold. The most important one is DS, followed by PS2, Wii and PS3.

# %% [markdown]
# + **Visualization Metric**

# %% [markdown]
# ![games_2-2.png](attachment:games_2-2.png)

# %% [markdown]
# In this metric we have the total sales for all the video games that appear in the dataset (units sold in Millions)

# %% [markdown]
# + **Line Plot**

# %% [markdown]
# ![games_3.png](attachment:games_3.png)

# %% [markdown]
# We can visualize here the evolution of sales during the period 1980-2015 grouped by Region.

# %% [markdown]
# + **Donut Chart**

# %% [markdown]
# ![games_4.png](attachment:games_4.png)

# %% [markdown]
# In this donut chart we can visualize the information related to the top 10 publishers according to the Video Games launched on the market.

# %% [markdown]
# + **Ranking with top 10 Selling Games**

# %% [markdown]
# ![games_5.png](attachment:games_5.png)

# %% [markdown]
# Here we can see a Ranking of the most sold games in the EU during the period 1980-2015.

# %% [markdown]
# + **Stacked Bar Chart**

# %% [markdown]
# ![games_6.png](attachment:games_6.png)

# %% [markdown]
# In this bar chart we can visualize the evolution of the most popular video game genres (top 5 genres for each year).

# %% [markdown]
# ### Nivell 3
#
# ### - Exercici 1
# Implementa un dashboard que generi gràfics utilitzant cadascun dels diferents tipus de gràfics que ofereix Kibana.

# %% [markdown]
# We have already used several visualizations for our data in the previous exercise, so this time we will use a sample dataset from Kibana itself that contains info about the traffic to a website. We will try to show all the different types of visualizations that Kibana offers.

# %% [markdown]
# + **Gauge and Metrics Visualization**

# %% [markdown]
# ![gauge_metric_visualization_windows_users.png](attachment:gauge_metric_visualization_windows_users.png)

# %% [markdown]
# In this panel we got the info of the number of visits to the web filtered by OS : Windows in the last 7 days. We have a total of 945 Visits and 603 Unique Visitors.

# %% [markdown]
# + **Map Visualization**

# %% [markdown]
# ![map_connections_and_bytes_atlanta.png](attachment:map_connections_and_bytes_atlanta.png)

# %% [markdown]
# In this map we see the number of connections in each city. In the screenshot we observe the example of Atlanta City: 75 connections and 432310 total bytes.

# %% [markdown]
# + **Bar Chart**

# %% [markdown]
# ![Stacked_bar_chart.png](attachment:Stacked_bar_chart.png)

# %% [markdown]
# In this chart we can visualize the distribution of connections for last week according to time of day (bins every 3 hours) and grouped by Response Code.

# %% [markdown]
# + **Pie Chart**

# %% [markdown]
# ![pie_chart.png](attachment:pie_chart.png)

# %% [markdown]
# With this pie chart we can visualize the tags keywords for all connections: the most common ones are 'success' (42.98% of connections) and the least common is 'error' (3.19% of connections).

# %% [markdown]
# + **Table**

# %% [markdown]
# ![Table.png](attachment:Table.png)

# %% [markdown]
# We can also create a visualization table: in this case we have info of URL connections, its total number of visits, the sum of total bytes and the average of bytes per connection.

# %% [markdown]
# + **Heatmap**

# %% [markdown]
# ![Heatmap.png](attachment:Heatmap.png)

# %% [markdown]
# Here we can visualize a heatmap of connections according to hour of day and OS. In the screenshot we can see the info of connections at 21 h for IOS (3 connections).

# %% [markdown]
# + **Line Chart**

# %% [markdown]
# ![line_chart.png](attachment:line_chart.png)

# %% [markdown]
# In this line chart we got info about the average Bytes per connection according to time of the Day, it seems to remain fairly stable throughout the day.
